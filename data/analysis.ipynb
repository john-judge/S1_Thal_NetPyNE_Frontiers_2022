# %%
import matplotlib.pyplot as plt
import numpy as np
import pandas as pd
import os 
import subprocess
import sys

# pickle
import pickle

# %%
run_id = 1
compart_data = {'soma': None}
compart_data = {**compart_data, **{'axon_' + str(i): None for i in range(50, 501, 50)}}
compart_data = {**compart_data, **{'dend_' + str(i): None for i in range(50, 501, 50)}}
compart_data = {**compart_data, **{'apic_' + str(i): None for i in range(50, 501, 50)}}

data_dir = 'C:/Users/jjudge3/Desktop/neuron docker/'

# extract all the .tar.gz files
for compart in compart_data.keys():
    target_dir = data_dir + 'archive/run' + str(run_id)
    if not os.path.exists(target_dir):
        os.makedirs(target_dir)
    target_dir += '/' + compart
    if not os.path.exists(target_dir):
        os.makedirs(target_dir)
    file = 'S1-Thal-output-' + compart  + '.tar.gz'
    full_file = data_dir + file
    if not os.path.exists(full_file):
        print('File ' + full_file + ' does not exist')
        continue
    result = subprocess.run(['tar', '-xzvf', full_file, '-C', target_dir], capture_output=True, text=True, check=True)
    #os.rename(full_file, data_dir + 'archive/' + file)
    #print('Extracted ' + full_file + ' to ' + target_dir + " then moved to archive/")
# Out:
# File C:/Users/jjudge3/Desktop/neuron docker/S1-Thal-output-axon_50.tar.gz does not exist

# %%
# load dend_500, axon_500, apic_500 pkl files and see if they have cell data
loaded_compart_data = {}
for compart in ['dend_500', 'axon_500', 'apic_500']:
    target_dir = data_dir + 'archive/run' + str(run_id) + '/' + compart
    if not os.path.exists(target_dir):
        print('Directory ' + target_dir + ' does not exist')
        continue
    target_dir += '/S1_Thal_NetPyNE_Frontiers_2022/data/v7_batch1/'
    data_file = target_dir + 'v7_batch1_0_0_data.pkl'

    if not os.path.exists(data_file):
        print("Data file not found:", data_file)
        continue
    # Load data
    with open(data_file, 'rb') as f:
        data = pickle.load(f)
        print(data.keys())
        loaded_compart_data[compart] = data

        print(data['simData'].keys())
# Out:
# dict_keys(['netpyne_version', 'netpyne_changeset', 'net', 'simConfig', 'simData'])
# dict_keys(['spkt', 'spkid', 'stims', 'Vdend_450', 'Vdend_451', 'Vdend_452', 'Vdend_453', 'Vdend_454', 'Vdend_455', 'Vdend_456', 'Vdend_457', 'Vdend_458', 'Vdend_459', 'Vdend_460', 'Vdend_461', 'Vdend_462', 'Vdend_463', 'Vdend_464', 'Vdend_465', 'Vdend_466', 'Vdend_467', 'Vdend_468', 'Vdend_469', 'Vdend_470', 'Vdend_471', 'Vdend_472', 'Vdend_473', 'Vdend_474', 'Vdend_475', 'Vdend_476', 'Vdend_477', 'Vdend_478', 'Vdend_479', 'Vdend_480', 'Vdend_481', 'Vdend_482', 'Vdend_483', 'Vdend_484', 'Vdend_485', 'Vdend_486', 'Vdend_487', 'Vdend_488', 'Vdend_489', 'Vdend_490', 'Vdend_491', 'Vdend_492', 'Vdend_493', 'Vdend_494', 'Vdend_495', 'Vdend_496', 'Vdend_497', 'Vdend_498', 'Vdend_499', 'Vdend_500', 't', 'popRates', 'avgRate'])
# dict_keys(['netpyne_version', 'netpyne_changeset', 'net', 'simConfig', 'simData'])
# ...

# %%
for compart in ['dend_500', 'axon_500', 'apic_500']:
    print(loaded_compart_data['simData']['V' + compart].keys())

# %%
for compartment in compart_data.keys():
    print("Loading data for", compartment)

    if compart_data[compartment] is not None:
        continue
    data_dir = 'C:/Users/jjudge3/Desktop/neuron docker/archive/run' + str(run_id) + '/' + compartment + '/S1_Thal_NetPyNE_Frontiers_2022/data/v7_batch1/'
    data_file = data_dir + 'v7_batch1_0_0_data.pkl'

    if not os.path.exists(data_file):
        print("Data file not found:", data_file)
        continue

    # Load data
    with open(data_file, 'rb') as f:
        data = pickle.load(f)
        print(data.keys())
        compart_data[compartment] = data

    break
# Out:
# Loading data for soma
# dict_keys(['netpyne_version', 'netpyne_changeset', 'net', 'simConfig', 'simData'])

# %%
n_cell = 40
n_cell_key = 'cell_' + str(n_cell)

soma_data = compart_data['soma']
while (n_cell_key not in soma_data['simData']['Vsoma']) or type(soma_data['simData']['Vsoma'][n_cell_key]) != list:
    print('Cell does not exist.')

    # random choice from existing cells
    n_cell_key = np.random.choice(list(soma_data['simData']['Vsoma'].keys()))
    n_cell = int(n_cell_key.split('_')[1])
    print('Randomly selected cell: ' + n_cell_key)

# plot trace for cell 
plt.figure()
plt.plot(soma_data['simData']['t'], soma_data['simData']['Vsoma'][n_cell_key])
plt.xlabel('Time (ms)')
plt.ylabel('Voltage (mV)')
plt.title('Soma Voltage for ' + n_cell_key)
plt.savefig('soma_voltage_' + n_cell_key + '.png')
plt.show()
# Out:
# Cell does not exist.
# Randomly selected cell: cell_35705
# Cell exists:

# %%
spkt = data['simData']['spkt']
spkid = data['simData']['spkid']
Vapic_0 = data['simData']['Vapic_0']
print('spkt:', spkt)
print('spkid:', spkid)
print('Vapic_0:', Vapic_0)
# Out:
# spkt: [0.7500000000999993, 0.7500000000999993, 0.7500000000999993, 0.7500000000999993, 0.7500000000999993, 0.7500000000999993, 0.7500000000999993, 0.7500000000999993, 0.7500000000999993, 0.7500000000999993, 0.7500000000999993, 0.7500000000999993, 0.7500000000999993, 0.7500000000999993, 0.7500000000999993, 0.7500000000999993, 0.7500000000999993, 0.7500000000999993, 0.7500000000999993, 0.7500000000999993, 0.7500000000999993, 0.7500000000999993, 0.7500000000999993, 0.7500000000999993, 0.7500000000999993, 0.7500000000999993, 0.7500000000999993, 0.7500000000999993, 0.7500000000999993, 0.7500000000999993, 0.7500000000999993, 0.7500000000999993, 0.7500000000999993, 0.7500000000999993, 0.7500000000999993, 0.7500000000999993, 0.7500000000999993, 0.7500000000999993, 0.7500000000999993, 0.7500000000999993, 0.7500000000999993, 0.7500000000999993, 0.7500000000999993, 0.7500000000999993, 0.7500000000999993, 0.7500000000999993, 0.7500000000999993, 0.7500000000999993, 0.7500000000999993, 0.750000000
# ...

# %%
n_traces = 0
for k in data['simData'].keys():
    if k.startswith("V") and "_" in k:
        #print(k)
        #print("\t", len(data['simData'][k]))
        n_traces += len(data['simData'][k])
print("n_traces:", n_traces)
# Out:
# n_traces: 0
